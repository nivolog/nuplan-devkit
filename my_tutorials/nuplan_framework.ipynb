# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | ~1300h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_60646/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
# SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
SAVE_DIR = Path('/hdd/vladislav/nuplan-results')
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = str(SAVE_DIR / EXPERIMENT / JOB_NAME)

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {LOG_DIR}

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'idm_planner' #'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback...
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback: 4...DONE!
# 2023-03-26 02:02:54,288 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-03-26 02:02:54,401 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-03-26 02:02:56,285	INFO worker.py:1553 -- Started a local Ray instance.
# 2023-03-26 02:02:57,208 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-03-26 02:02:57,209 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2023-03-26 02:02:57,209 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-03-26 02:02:57,209 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:29}  Building experiment folders...
# 2023-03-26 02:02:57,209 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}
#
# 	Folder where all results are stored: /hdd/vladislav/nuplan-results/simulation_simple_experiment/open_loop_boxes/2023.03.26.02.02.53
#
# 2023-03-26 02:02:57,210 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:63}  Building experiment folders...DONE!
# 2023-03-26 02:02:57,210 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-03-26 02:02:57,317 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-03-26 02:02:57,317 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-03-26 02:02:57,317 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2023-03-26 02:02:57,317 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:46}  Building simulations...
# 2023-03-26 02:02:57,317 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-03-26 02:02:57,318 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-03-26 02:02:57,318 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# Ray objects: 100%|███████████████████████████████████████████████████████| 12/12 [00:05<00:00,  2.08it/s]
# 2023-03-26 02:03:03,135 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios 31...DONE!
# 2023-03-26 02:03:03,136 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:59}  Building metric engines...
# 2023-03-26 02:03:03,217 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:61}  Building metric engines...DONE
# 2023-03-26 02:03:03,217 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:65}  Building simulations from 31 scenarios...
# 2023-03-26 02:03:03,835 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:121}  Building simulations...DONE!
# 2023-03-26 02:03:03,835 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Running simulation...
# 2023-03-26 02:03:03,835 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/utils.py:135}  Executing runners...
# 2023-03-26 02:03:03,835 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Ray objects:   0%|                                                                | 0/31 [00:00<?, ?it/s](raylet) [2023-03-26 02:03:06,181 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857945088; capacity: 490577010688. Object creation will fail if spilling is required.
# (wrapped_fn pid=61529) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# (wrapped_fn pid=61529) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61529)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61528) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61528)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61535) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61535)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61530) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61530)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61533) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61533)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61534) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61534)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61536) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61536)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61527) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61527)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61531) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61531)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61532) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61532)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61537) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61537)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61526) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# (wrapped_fn pid=61526) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61526)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (raylet) [2023-03-26 02:03:16,184 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857912320; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects:   3%|█▊                                                      | 1/31 [00:14<07:28, 14.96s/it](wrapped_fn pid=61529) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61529)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:   6%|███▌                                                    | 2/31 [00:20<04:31,  9.36s/it](raylet) [2023-03-26 02:03:26,189 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857887744; capacity: 490577010688. Object creation will fail if spilling is required.
# (wrapped_fn pid=61528) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# (wrapped_fn pid=61528) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61528)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  13%|███████▏                                                | 4/31 [00:26<02:16,  5.06s/it](wrapped_fn pid=61535) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61535)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61537) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# Ray objects:  19%|██████████▊                                             | 6/31 [00:29<01:12,  2.89s/it](wrapped_fn pid=61536) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61536)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  26%|██████████████▍                                         | 8/31 [00:31<00:44,  1.95s/it](raylet) [2023-03-26 02:03:36,203 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857826304; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects:  29%|████████████████▎                                       | 9/31 [00:32<00:33,  1.53s/it](wrapped_fn pid=61529) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61529)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  39%|█████████████████████▎                                 | 12/31 [00:34<00:19,  1.00s/it](wrapped_fn pid=61532) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61532)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  42%|███████████████████████                                | 13/31 [00:36<00:22,  1.24s/it](wrapped_fn pid=61534) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61534)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61533) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=61533)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# Ray objects:  45%|████████████████████████▊                              | 14/31 [00:41<00:41,  2.42s/it](raylet) [2023-03-26 02:03:46,207 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857805824; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects:  52%|████████████████████████████▍                          | 16/31 [00:46<00:37,  2.51s/it](wrapped_fn pid=62163) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# (wrapped_fn pid=62163) /hdd/vladislav/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=62163)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=61532) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# (raylet) [2023-03-26 02:03:56,182 E 61433 61433] (raylet) node_manager.cc:3040: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 2d420524e75bc9b9dba3b4e932a665246647b7a5dbe87c215c6e7d5d, IP: 192.168.0.128) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.0.128`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2023-03-26 02:03:56,210 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857768960; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects:  61%|█████████████████████████████████▋                     | 19/31 [00:55<00:29,  2.48s/it](wrapped_fn pid=61534) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# Ray objects:  65%|███████████████████████████████████▍                   | 20/31 [00:59<00:31,  2.83s/it](wrapped_fn pid=61533) WARNING:nuplan.planning.simulation.planner.idm_planner:IDMPlanner could not find valid path to the target roadblock. Using longest route found instead
# Ray objects:  71%|███████████████████████████████████████                | 22/31 [01:01<00:17,  1.95s/it](raylet) [2023-03-26 02:04:06,214 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857666560; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects:  97%|█████████████████████████████████████████████████████▏ | 30/31 [01:11<00:01,  1.30s/it](raylet) [2023-03-26 02:04:16,217 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857633792; capacity: 490577010688. Object creation will fail if spilling is required.
# Ray objects: 100%|███████████████████████████████████████████████████████| 31/31 [01:19<00:00,  2.55s/it]
# 2023-03-26 02:04:23,035 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2023-03-26 02:04:23,039 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2023-03-26 02:04:23,039 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/utils.py:144}  Finished executing runners!
# 2023-03-26 02:04:23,074 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/utils.py:71}  Saved runner reports to /hdd/vladislav/nuplan-results/simulation_simple_experiment/open_loop_boxes/2023.03.26.02.02.53/runner_report.parquet
# 2023-03-26 02:04:23,074 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:01:28 [HH:MM:SS]
# 2023-03-26 02:04:23,411 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:70}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-03-26 02:04:23,464 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:50}  Running metric aggregator: open_loop_boxes_weighted_average
# 2023-03-26 02:04:23,484 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:61}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|████████████████████████████████████████████████| 6/6 [00:01<00:00,  3.49it/s]
# 2023-03-26 02:04:26,147 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:339}  Metric summary: 00:00:02 [HH:MM:SS]
# 2023-03-26 02:04:26,148 INFO {/hdd/vladislav/nuplan-devkit/nuplan/planning/script/run_simulation.py:82}  Finished running simulation!
# (raylet) [2023-03-26 02:04:26,221 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857613312; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:04:36,227 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857539584; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:04:46,235 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857564160; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:04:56,184 E 61433 61433] (raylet) node_manager.cc:3040: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 2d420524e75bc9b9dba3b4e932a665246647b7a5dbe87c215c6e7d5d, IP: 192.168.0.128) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.0.128`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2023-03-26 02:04:56,242 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857523200; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:06,248 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857519104; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:16,256 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857510912; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:26,264 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857502720; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:36,271 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857498624; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:46,279 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857490432; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:05:56,285 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857457664; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:06,293 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857404416; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:16,301 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857396224; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:26,308 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857392128; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:36,315 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857375744; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:46,322 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857359360; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:06:56,329 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857334784; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:06,337 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857322496; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:16,344 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857318400; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:26,351 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857302016; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:36,358 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857285632; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:46,366 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857277440; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:07:56,374 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857240576; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:06,381 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857195520; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:16,388 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6857179136; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:26,394 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848753664; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:36,401 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848749568; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:46,409 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848741376; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:08:56,416 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848684032; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:06,423 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848692224; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:16,430 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848688128; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:26,437 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848688128; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:36,445 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848688128; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:46,453 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848684032; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:09:56,461 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848663552; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:06,468 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848569344; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:16,475 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848557056; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:26,482 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848552960; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:36,489 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848532480; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:46,497 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848524288; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:10:56,504 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848495616; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:06,512 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848503808; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:16,520 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848503808; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:26,527 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848499712; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:36,535 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848499712; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:46,541 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848495616; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:11:56,549 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848471040; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:06,557 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848421888; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:16,565 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848417792; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:26,572 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848417792; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:36,580 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848413696; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:46,587 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848397312; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:12:56,595 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848368640; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:06,602 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848356352; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:16,609 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848356352; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:26,616 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848356352; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:36,624 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848352256; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:46,631 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848352256; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:13:56,638 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848327680; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:06,645 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848278528; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:16,653 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848278528; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:26,661 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848274432; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:36,668 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848270336; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:46,675 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848253952; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:14:56,683 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848229376; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:06,690 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848217088; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:16,698 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848212992; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:26,705 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848212992; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:36,713 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848188416; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:46,721 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848188416; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:15:56,729 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848167936; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:06,736 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848126976; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:16,743 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848126976; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:26,751 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848126976; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:36,758 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848118784; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:46,766 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848114688; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:16:56,774 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848081920; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:06,781 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848073728; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:16,789 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848073728; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:26,796 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848069632; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:36,803 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848069632; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:46,810 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848065536; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:17:56,817 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6848040960; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:06,825 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847995904; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:16,832 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847987712; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:26,839 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847987712; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:36,847 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847979520; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:46,854 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847975424; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:18:56,861 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847909888; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:06,868 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847877120; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:16,875 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847877120; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:26,882 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847877120; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:36,889 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847873024; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:46,896 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847873024; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:19:56,904 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847848448; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:06,910 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847832064; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:16,917 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847827968; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:26,925 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847823872; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:36,933 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847807488; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:46,941 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847799296; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:20:56,948 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847774720; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:06,955 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847741952; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:16,963 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847737856; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:26,971 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847737856; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:36,979 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847721472; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:46,986 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847717376; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:21:56,993 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847696896; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:07,000 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847680512; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:17,006 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847680512; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:27,013 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847680512; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:37,020 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847660032; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:47,028 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847655936; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:22:57,036 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847627264; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:23:07,043 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847594496; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 02:23:17,051 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6847594496; capacity: 490577010688. Object creation will fail if spilling is required.
# ...
# (raylet) [2023-03-26 14:06:18,076 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713540608; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:06:28,083 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713540608; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:06:38,091 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713532416; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:06:48,098 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713528320; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:06:58,105 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713503744; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:08,113 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713483264; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:18,121 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713483264; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:28,129 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713466880; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:38,137 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713466880; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:48,145 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713466880; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:07:58,153 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713454592; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:08,161 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713417728; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:18,169 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713413632; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:28,177 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713413632; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:38,184 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713405440; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:48,192 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713401344; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:08:58,199 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713372672; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:08,206 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713352192; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:18,214 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713352192; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:28,221 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713401344; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:38,229 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713393152; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:48,236 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713393152; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:09:58,244 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713372672; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:08,252 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713339904; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:18,260 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713327616; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:28,267 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713323520; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:38,273 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713315328; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:48,280 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713315328; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:10:58,286 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713282560; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:08,293 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713262080; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:18,299 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713257984; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:28,305 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713257984; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:38,311 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713253888; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:48,318 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713249792; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:11:58,325 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713225216; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:08,331 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713196544; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:18,337 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713196544; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:28,343 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713196544; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:38,350 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713171968; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:48,356 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713171968; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:12:58,363 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713143296; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:08,370 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713122816; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:18,378 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713122816; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:28,386 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713110528; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:38,394 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713106432; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:48,402 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713106432; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:13:58,409 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713094144; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:08,416 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713069568; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:18,424 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713065472; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:28,431 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713057280; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:38,438 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713049088; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:48,445 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713044992; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:14:58,453 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6713020416; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:08,460 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712913920; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:18,468 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712860672; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:28,475 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712827904; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:38,483 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712860672; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:48,490 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712856576; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:15:58,497 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712836096; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:16:08,504 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712815616; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:16:18,512 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712766464; capacity: 490577010688. Object creation will fail if spilling is required.
# (raylet) [2023-03-26 14:16:28,520 E 61433 61467] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-03-26_02-02-54_430988_60646 is over 95% full, available space: 6712766464; capacity: 490577010688. Object creation will fail if spilling is required.

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(Path(LOG_DIR).iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
